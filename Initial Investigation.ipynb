# %%
import pandas as pd
from sqlalchemy import create_engine

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load data from postgreSQL
engine = create_engine('postgresql://postgres:apassword@localhost:5432/postgres')
df = pd.read_sql_table('yelp_businesses_clean', con=engine) 

print(len(df))
# Out:
# 1000

# %%
# inspect data
df.head(1)
# Out:
#          address1 address2 address3                      alias  australian  \
# 0  257 Hanover St                    modern-pastry-shop-boston       False
#
#    bagels  bakeries  banks  barbers   bars    ...     vegetarian  venezuelan  \
# 0   False     False  False    False  False    ...          False       False
#
#    venues  videoandgames  vietnamese  waffles  wholesale_stores  wine_bars  \
# 0   False          False       False    False             False      False
#
#    wraps  zip_code
# 0  False     02113
#
# [1 rows x 109 columns]

# %%
# look at data types
df.dtypes
# Out:
# address1                    object
# address2                    object
# address3                    object
# alias                       object
# australian                    bool
# bagels                        bool
# bakeries                      bool
# banks                         bool
# barbers                       bool
# bars                          bool
# basque                        bool
# beer_and_wine                 bool
# beerbar                       bool
# bike_repair_maintenance       bool
# bikes                         bool
# bookstores                    bool
# breakfast_brunch              bool
# breweries                     bool
# bubbletea                     bool
# burgers                       bool
# cafes                         bool
# cakeshop                      bool
# candy                         bool
# cantonese                     bool
# caribbean                     bool
# catering                      bool
# chocolate                     bool
# city                        object
# cocktailbars                  bool
# coffee                        bool
#                             ...
# ramen                         bool
# rating                     float64
# restaurants                   bool
# review_count                 int64
# salad                         bool
# sandwiches                    bool
# seafood                       bool
# servicestations               bool
# soup                          bool
# souvenirs                     bool
# spanish                       bool
# state                       object
# sushi                         bool
# tabletopgames                 bool
# tapasmallplates               bool
# tattoo                        bool
# tea                           bool
# tradamerican                  bool
# url                         object
# vegan                         bool
# vegetarian                    bool
# venezuelan                    bool
# venues                        bool
# videoandgames                 bool
# vietnamese                    bool
# waffles                       bool
# wholesale_stores              bool
# wine_bars                     bool
# wraps                         bool
# zip_code                    object
# Length: 109, dtype: object

# %%
# plot the number of businesses by rating
df.rating.value_counts().plot(kind='barh', title='Ratings')
plt.show()

# %%
# plot the number of businesses by city
df.city.value_counts().plot(kind='bar', title='Number of busineses by city', figsize=(16, 6))
plt.show()
